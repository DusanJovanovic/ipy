# %% [markdown]
# # Exercise notebook 2: Cleaning up our act
# This Jupyter notebook, for Week 2 of The Open University's [Learn to code for Data Analysis](https://www.futurelearn.com/courses/learn-to-code/) course, has code examples and coding activities for you. Remember to run the code in this notebook before you start.
#
# You'll come across steps in the FutureLearn course directing you to this notebook. Once you've done the exercise, go back to FutureLearn to discuss it with your fellow learners and course facilitators and mark it as complete.

# %%
from pandas import *

# %% [markdown]
# ## Exercise 1: Dataframes and CSV files
#
# To read a CSV file into a dataframe you need to call the pandas function called <code>read_csv()</code>. The simplest usage of this function is with a single argument, a string that holds the name of the CSV file, for example.

# %%
df = read_csv('WHO POP TB all.csv')

# %% [markdown]
# ### Dataframe attributes
#
# An dataframe attribute is like a variable that can only be accessed in the context of a dataframe. Once such attribute is <code>columns</code> which holds a dataframe's column names.

# %%
df.columns
# Out:
# Index([u'Country', u'Population (1000s)', u'TB deaths'], dtype='object')

# %% [markdown]
# ### Dataframe rows
# A dataframe has a default integer index for its rows, which starts at zero <code>0</code>. The `irow()` method returns the row at the given index.

# %%
df.iloc[0] # first row, index 0
# Out:
# Country               Afghanistan
# Population (1000s)          30552
# TB deaths                   13000
# Name: 0, dtype: object

# %%
df.iloc[2] # third row, index 2
# Out:
# Country               Algeria
# Population (1000s)      39208
# TB deaths                5100
# Name: 2, dtype: object

# %% [markdown]
# ### The <code>head()</code> method
#
# The `head()` method returns a dataframe with the first rows, as many as given in the argument. By default, if the argument is missing, it returns the first five rows.

# %%
df.head() # first five rows
# Out:
#        Country  Population (1000s)  TB deaths
# 0  Afghanistan               30552   13000.00
# 1      Albania                3173      20.00
# 2      Algeria               39208    5100.00
# 3      Andorra                  79       0.26
# 4       Angola               21472    6900.00

# %%
df.head(7) # first seven rows
# Out:
#                Country  Population (1000s)  TB deaths
# 0          Afghanistan               30552   13000.00
# 1              Albania                3173      20.00
# 2              Algeria               39208    5100.00
# 3              Andorra                  79       0.26
# 4               Angola               21472    6900.00
# 5  Antigua and Barbuda                  90       1.20
# 6            Argentina               41446     570.00

# %% [markdown]
# ### The <code>tail()</code> method
# The <code>tail()</code> method is similar to the <code>head()</code> method. If no argument is used, the last five rows of the dataframe are returned, otherwise the number of rows returned is dependent on the argument.

# %%
df.tail() # last five rows
# Out:
#                                 Country  Population (1000s)  TB deaths
# 189  Venezuela (Bolivarian Republic of)               30405        480
# 190                            Viet Nam               91680      17000
# 191                               Yemen               24407        990
# 192                              Zambia               14539       3600
# 193                            Zimbabwe               14150       5700

# %% [markdown]
# ### Selecting and displaying columns in a dataframe
# You found in Week 1 that you can select and display the values for a single dataframe column by puting the name of the column (in quotes) within square brackets immediately after the dataframe's name. However you can also select and display the values for multiple columns too.
#
# To get multiple columns you need to use a list. A list in Python is a number of items separated by commas within square brackets, for example `['Country', 'Population (1000s)']`. This list is then put within square brackets immediately after the dataframe's name. The resulting expression represents a new dataframe, just with those columns, and therefore any dataframe method can be applied to it, like for example `head()`:

# %%
df[['Country', 'Population (1000s)']].head()
# Out:
#        Country  Population (1000s)
# 0  Afghanistan               30552
# 1      Albania                3173
# 2      Algeria               39208
# 3      Andorra                  79
# 4       Angola               21472

# %% [markdown]
# ### Applying methods to a dataframe column
# The `irow()`, <code>head()</code> and <code>tail()</code> methods discussed above can be used with single columns.

# %%
df['TB deaths'].iat[2] # third value of deaths column
# Out:
# 5100.0

# %%
df['Population (1000s)'].tail() # last five values of population column
# Out:
# 189    30405
# 190    91680
# 191    24407
# 192    14539
# 193    14150
# Name: Population (1000s), dtype: int64

# %% [markdown]
# ### Tasks
#
# In the code cell below, write the code to get and display the 55th row in the dataframe <code>df</code>.

# %%
df.iloc[55]
# Out:
# Country               Equatorial Guinea
# Population (1000s)                  757
# TB deaths                            67
# Name: 55, dtype: object

# %% [markdown]
# In the code cell below write the code to display the first 10 rows of the dataframe <code>df</code>.

# %%
df.head(10)
# Out:
#                Country  Population (1000s)  TB deaths
# 0          Afghanistan               30552   13000.00
# 1              Albania                3173      20.00
# 2              Algeria               39208    5100.00
# 3              Andorra                  79       0.26
# 4               Angola               21472    6900.00
# 5  Antigua and Barbuda                  90       1.20
# 6            Argentina               41446     570.00
# 7              Armenia                2977     170.00
# 8            Australia               23343      45.00
# 9              Austria                8495      29.00

# %% [markdown]
# In the code cell below, select and display the first eight rows from the <code>'Country'</code> and <code>'TB deaths'</code> columns.

# %%
df[["Country", "TB deaths"]].head(8)
# Out:
#                Country  TB deaths
# 0          Afghanistan   13000.00
# 1              Albania      20.00
# 2              Algeria    5100.00
# 3              Andorra       0.26
# 4               Angola    6900.00
# 5  Antigua and Barbuda       1.20
# 6            Argentina     570.00
# 7              Armenia     170.00

# %% [markdown]
# **Now go back to the Exercise 1 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ## Exercise 2: Comparison operators
# Python has the following comparison operators:
#
#     == (equals)
#     != (not equal)
#     < (less than)
#     > (greater than)
#     <= (less than or equal to)
#     >= (greater than or equal to)
#
# The following code will get and display all the rows in `df` where it is `True` that the value in the `'Population (1000s)'` column is greater than `80000`.

# %%
df[df['Population (1000s)'] > 80000]
# Out:
#                       Country  Population (1000s)  TB deaths
# 13                 Bangladesh              156595      80000
# 23                     Brazil              200362       4400
# 36                      China             1393337      41000
# 53                      Egypt               82056        550
# 58                   Ethiopia               94101      30000
# 65                    Germany               82727        300
# 77                      India             1252140     240000
# 78                  Indonesia              249866      64000
# 85                      Japan              127144       2100
# 109                    Mexico              122332       2200
# 124                   Nigeria              173615     160000
# 128                  Pakistan              182143      49000
# 134               Philippines               98394      27000
# 141        Russian Federation              142834      17000
# 185  United States of America              320051        490
# 190                  Viet Nam               91680      17000

# %% [markdown]
# ### Task
# In the code cell below write code to find all the rows in <code>df</code> where TB deaths exceed 10000.

# %%
df[df['TB deaths'] > 10000]
# Out:
#                               Country  Population (1000s)  TB deaths
# 0                         Afghanistan               30552      13000
# 13                         Bangladesh              156595      80000
# 36                              China             1393337      41000
# 47   Democratic Republic of the Congo               67514      46000
# 58                           Ethiopia               94101      30000
# 77                              India             1252140     240000
# 78                          Indonesia              249866      64000
# 100                        Madagascar               22925      12000
# 115                        Mozambique               25834      18000
# 116                           Myanmar               53259      26000
# 124                           Nigeria              173615     160000
# 128                          Pakistan              182143      49000
# 134                       Philippines               98394      27000
# 141                Russian Federation              142834      17000
# 159                      South Africa               52776      25000
# 190                          Viet Nam               91680      17000

# %% [markdown]
# **Now go back to the Exercise 2 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ## Exercise 3: Bitwise operators
#
# Pandas has two operators to make more complicated queries. Use the operator `&` (means 'and') to select rows where two conditions are both true. Use the operator `|` (means 'or') to select rows where at least one condition is true. Don't forget to put parentheses around _each_ comparison. For example, the following expression selects only countries with a population over 80 million inhabitants **and** with more that 10 thousand deaths.

# %%
df[(df['Population (1000s)'] > 80000) & (df['TB deaths'] > 10000)]
# Out:
#                 Country  Population (1000s)  TB deaths
# 13           Bangladesh              156595      80000
# 36                China             1393337      41000
# 58             Ethiopia               94101      30000
# 77                India             1252140     240000
# 78            Indonesia              249866      64000
# 124             Nigeria              173615     160000
# 128            Pakistan              182143      49000
# 134         Philippines               98394      27000
# 141  Russian Federation              142834      17000
# 190            Viet Nam               91680      17000

# %% [markdown]
# If the same columns will be used repeatedly in the program, the code becomes more readable if written as follows:

# %%
population = df['Population (1000s)']
deaths = df['TB deaths']
df[(population > 80000) & (deaths > 10000)]
# Out:
#                 Country  Population (1000s)  TB deaths
# 13           Bangladesh              156595      80000
# 36                China             1393337      41000
# 58             Ethiopia               94101      30000
# 77                India             1252140     240000
# 78            Indonesia              249866      64000
# 124             Nigeria              173615     160000
# 128            Pakistan              182143      49000
# 134         Philippines               98394      27000
# 141  Russian Federation              142834      17000
# 190            Viet Nam               91680      17000

# %% [markdown]
# ### Task
# In the code cell below find  all the countries where the Population (1000s) is **less than or equal to** 50000 **or** TB deaths are **greater than or equal to** 20000.

# %%
df[(df['Population (1000s)'] <= 50000) | (df['TB deaths'] >= 20000)]
# Out:
#                                        Country  Population (1000s)  TB deaths
# 0                                  Afghanistan               30552   13000.00
# 1                                      Albania                3173      20.00
# 2                                      Algeria               39208    5100.00
# 3                                      Andorra                  79       0.26
# 4                                       Angola               21472    6900.00
# 5                          Antigua and Barbuda                  90       1.20
# 6                                    Argentina               41446     570.00
# 7                                      Armenia                2977     170.00
# 8                                    Australia               23343      45.00
# 9                                      Austria                8495      29.00
# 10                                  Azerbaijan                9413     360.00
# 11                                     Bahamas                 377       1.80
# 12                                     Bahrain                1332       9.60
# 13                                  Bangladesh              156595   80000.00
# 14                                    Barbados                 285       2.00
# 15                                     Belarus                9357     850.00
# 16                                     Belgium               11104      18.00
# 17                                      Belize                 332      20.00
# 18                                       Benin               10323    1300.00
# 19                                      Bhutan                 754      88.00
# 20            Bolivia (Plurinational State of)               10671     430.00
# 21                      Bosnia and Herzegovina                3829     190.00
# 22                                    Botswana                2021     440.00
# 24                           Brunei Darussalam                 418      13.00
# 25                                    Bulgaria                7223     150.00
# 26                                Burkina Faso               16935    1500.00
# 27                                     Burundi               10163    2300.00
# 28                               Côte d'Ivoire               20316    4000.00
# 29                                  Cabo Verde                 499     150.00
# 30                                    Cambodia               15135   10000.00
# ..                                         ...                 ...        ...
# 159                               South Africa               52776   25000.00
# 160                                South Sudan               11296    4500.00
# 161                                      Spain               46927     240.00
# 162                                  Sri Lanka               21273    1300.00
# 163                                      Sudan               37964    9700.00
# 164                                   Suriname                 539      12.00
# 165                                  Swaziland                1250    1100.00
# 166                                     Sweden                9571      13.00
# 167                                Switzerland                8078      17.00
# 168                       Syrian Arab Republic               21898     450.00
# 169                                 Tajikistan                8208     570.00
# 171  The former Yugoslav republic of Macedonia                2107      33.00
# 172                                Timor-Leste                1133     990.00
# 173                                       Togo                6817     810.00
# 174                                      Tonga                 105       2.50
# 175                        Trinidad and Tobago                1341      29.00
# 176                                    Tunisia               10997     230.00
# 178                               Turkmenistan                5240    1300.00
# 179                                     Tuvalu                  10       2.80
# 180                                     Uganda               37579    4100.00
# 181                                    Ukraine               45239    6600.00
# 182                       United Arab Emirates                9346      64.00
# 184                United Republic of Tanzania               49253    6000.00
# 186                                    Uruguay                3407      40.00
# 187                                 Uzbekistan               28934    2200.00
# 188                                    Vanuatu                 253      16.00
# 189         Venezuela (Bolivarian Republic of)               30405     480.00
# 191                                      Yemen               24407     990.00
# 192                                     Zambia               14539    3600.00
# 193                                   Zimbabwe               14150    5700.00
#
# [180 rows x 3 columns]

# %% [markdown]
# **Now go back to the Exercise 3 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ## Exercise 4: Display rows from dataframe
#
# The 2014 Weather Underground data for London has been downloaded from the site as a CSV file and can now be read into a dataframe.

# %%
london = read_csv('London_2014.csv')
london.head()
# Out:
#         GMT  Максимална температураC  Средња температураC  \
# 0  2014-1-1                       11                    8
# 1  2014-1-2                       11                    9
# 2  2014-1-3                       11                    8
# 3  2014-1-4                        9                    6
# 4  2014-1-5                       12                    7
#
#    Минимална температураC  Тачка росеC  MeanDew PointC  Min DewpointC  \
# 0                       6            9               7              4
# 1                       6            9               6              4
# 2                       6            9               5              2
# 3                       3            8               6              2
# 4                       1           11               4             -1
#
#    Max Влажност ваздуха   Mean Влажност ваздуха   Min Влажност ваздуха  \
# 0                    94                      86                     73
# 1                    94                      81                     60
# 2                    94                      76                     54
# 3                    93                      85                     65
# 4                   100                      88                     77
#
#            ...            Max ВидљивостKm   Mean ВидљивостKm  \
# 0          ...                         31                 11
# 1          ...                         31                 15
# 2          ...                         31                 12
# 3          ...                         31                 12
# 4          ...                         31                 14
#
#     Min ВидљивостkM   Max Брзина ветраKm/h   Mean Брзина ветраKm/h  \
# 0                 2                     40                      26
# 1                 5                     32                      21
# 2                 0                     50                      29
# 3                 5                     35                      21
# 4                 5                     35                      16
#
#     Max Брзина удара ветраKm/h  Падавинеmm   CloudCover  \
# 0                           66        9.91            4
# 1                           50        1.02            2
# 2                           69        7.11            2
# 3                           39        9.91            4
# 4                          NaN        0.25            5
#
#                   Догађаји  WindDirDegrees<br />
# 0                     Киша             186<br />
# 1                     Киша             214<br />
# 2  Киша-Олуја с грмљавином             219<br />
# 3                     Киша             211<br />
# 4                     Киша             199<br />
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Removing initial spaces
#
# There are too many columns for the dataframe to fit horizontally in this notebook, but they can be displayed separately.

# %%
london.columns
# Out:
# Index([u'GMT', u'Максимална температураC', u'Средња температураC',
#        u'Минимална температураC', u'Тачка росеC', u'MeanDew PointC',
#        u'Min DewpointC', u'Max Влажност ваздуха', u' Mean Влажност ваздуха',
#        u' Min Влажност ваздуха', u' Max Ваздушни притисак на нивоу мораhPa',
#        u' Mean Ваздушни притисак на нивоу мораhPa',
#        u' Min Ваздушни притисак на нивоу мораhPa', u' Max ВидљивостKm',
#        u' Mean ВидљивостKm', u' Min ВидљивостkM', u' Max Брзина ветраKm/h',
#        u' Mean Брзина ветраKm/h', u' Max Брзина удара ветраKm/h',
#        u'Падавинеmm', u' CloudCover', u' Догађаји', u'WindDirDegrees<br />'],
#       dtype='object')

# %% [markdown]
# This shows that <code>' Max Wind SpeedKm/h'</code> is prefixed by a space, as do other columm names such as <code>' Mean Humidity'</code> and <code>' Max Sea Level PressurehPa'</code>.
#
# The  <code>read_csv()</code> function has interpreted spaces after commas as being part of the next value. This can be rectified  easily by adding another argument to the <code>read_csv()</code> function to skiop the initial spaces after a comma.

# %%
london = read_csv('London_2014.csv', skipinitialspace=True)

# %%
london.head(5)
# Out:
#         GMT  Максимална температураC  Средња температураC  \
# 0  2014-1-1                       11                    8
# 1  2014-1-2                       11                    9
# 2  2014-1-3                       11                    8
# 3  2014-1-4                        9                    6
# 4  2014-1-5                       12                    7
#
#    Минимална температураC  Тачка росеC  MeanDew PointC  Min DewpointC  \
# 0                       6            9               7              4
# 1                       6            9               6              4
# 2                       6            9               5              2
# 3                       3            8               6              2
# 4                       1           11               4             -1
#
#    Max Влажност ваздуха  Mean Влажност ваздуха  Min Влажност ваздуха  \
# 0                    94                     86                    73
# 1                    94                     81                    60
# 2                    94                     76                    54
# 3                    93                     85                    65
# 4                   100                     88                    77
#
#            ...           Max ВидљивостKm  Mean ВидљивостKm  Min ВидљивостkM  \
# 0          ...                        31                11                2
# 1          ...                        31                15                5
# 2          ...                        31                12                0
# 3          ...                        31                12                5
# 4          ...                        31                14                5
#
#    Max Брзина ветраKm/h  Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  \
# 0                    40                     26                          66
# 1                    32                     21                          50
# 2                    50                     29                          69
# 3                    35                     21                          39
# 4                    35                     16                         NaN
#
#    Падавинеmm  CloudCover                 Догађаји  WindDirDegrees<br />
# 0        9.91           4                     Киша             186<br />
# 1        1.02           2                     Киша             214<br />
# 2        7.11           2  Киша-Олуја с грмљавином             219<br />
# 3        9.91           4                     Киша             211<br />
# 4        0.25           5                     Киша             199<br />
#
# [5 rows x 23 columns]

# %%
london.columns
# Out:
# Index([u'GMT', u'Максимална температураC', u'Средња температураC',
#        u'Минимална температураC', u'Тачка росеC', u'MeanDew PointC',
#        u'Min DewpointC', u'Max Влажност ваздуха', u'Mean Влажност ваздуха',
#        u'Min Влажност ваздуха', u'Max Ваздушни притисак на нивоу мораhPa',
#        u'Mean Ваздушни притисак на нивоу мораhPa',
#        u'Min Ваздушни притисак на нивоу мораhPa', u'Max ВидљивостKm',
#        u'Mean ВидљивостKm', u'Min ВидљивостkM', u'Max Брзина ветраKm/h',
#        u'Mean Брзина ветраKm/h', u'Max Брзина удара ветраKm/h', u'Падавинеmm',
#        u'CloudCover', u'Догађаји', u'WindDirDegrees<br />'],
#       dtype='object')

# %% [markdown]
# ### Removing extra characters
#
# Another problem shown above is that the final column is called <code>'WindDirDegrees&lt; br /&gt;'</code>.
#
# When the dataset was exported from the Weather Underground web site html line breaks were automatically added to each line in the file which <code>read_csv()</code> has interpreted as part of the column name and its values. This can be seen more clearly by looking at more values in the final column:

# %%
london['WindDirDegrees<br />'].head()
# Out:
# 0    186<br />
# 1    214<br />
# 2    219<br />
# 3    211<br />
# 4    199<br />
# Name: WindDirDegrees<br />, dtype: object

# %% [markdown]
# <code>'WindDirDegrees&lt; br /&gt;'</code> can be changed to <code>'WindDirDegrees'</code> with the <code>rename()</code> method as follows:

# %%
london = london.rename(columns={'WindDirDegrees<br />' : 'WindDirDegrees'})

# %% [markdown]
# To remove the <code>'&lt; br /&gt;'</code> html line breaks from the values in the <code>'WindDirDegrees'</code> column you need to use the string method <code>rstrip()</code> which is used to remove characters from the *end* or 'rear' of a string:

# %%
london['WindDirDegrees'] = london['WindDirDegrees'].str.rstrip('<br />')

# %% [markdown]
# Display the first few rows of the <code>'WindDirDegrees'</code> to confirm the change:

# %%
london['WindDirDegrees'].head()
# Out:
# 0    186
# 1    214
# 2    219
# 3    211
# 4    199
# Name: WindDirDegrees, dtype: object

# %% [markdown]
# ### Missing values
#
# Missing (also called null or not available) values are marked as NaN (not a number) in dataframes.

# %%
london['Догађаји'].tail()
# Out:
# 360     Киша
# 361      NaN
# 362      NaN
# 363      NaN
# 364    Магла
# Name: Догађаји, dtype: object

# %% [markdown]
# The `isnull()` method returns `True` for each row in a column that has a null value. The method can be used to select and display those rows. Scroll the table below to the right to check that the events column is only showing missing values.

# %%
london[london['Догађаји'].isnull()]
# Out:
#             GMT  Максимална температураC  Средња температураC  \
# 32     2014-2-2                       10                    8
# 33     2014-2-3                        8                    6
# 43    2014-2-13                        8                    6
# 52    2014-2-22                       12                    8
# 63     2014-3-5                       13                    7
# 64     2014-3-6                       13                    9
# 66     2014-3-8                       16                   11
# 67     2014-3-9                       19                   12
# 68    2014-3-10                       13                    8
# 70    2014-3-12                       16                    9
# 73    2014-3-15                       18                   12
# 74    2014-3-16                       19                   13
# 75    2014-3-17                       14                    9
# 77    2014-3-19                       16                   11
# 87    2014-3-29                       19                   13
# 92     2014-4-3                       18                   14
# 93     2014-4-4                       15                   12
# 98     2014-4-9                       17                   10
# 99    2014-4-10                       16                   11
# 100   2014-4-11                       16                   12
# 101   2014-4-12                       14                   10
# 102   2014-4-13                       16                   12
# 103   2014-4-14                       16                   11
# 104   2014-4-15                       14                    9
# 105   2014-4-16                       17                   10
# 106   2014-4-17                       17                   11
# 107   2014-4-18                       12                    9
# 108   2014-4-19                       14                    9
# 122    2014-5-3                       14                    8
# 123    2014-5-4                       16                   10
# ..          ...                      ...                  ...
# 252   2014-9-10                       21                   16
# 253   2014-9-11                       18                   14
# 254   2014-9-12                       23                   18
# 255   2014-9-13                       21                   17
# 257   2014-9-15                       22                   17
# 258   2014-9-16                       23                   18
# 259   2014-9-17                       21                   18
# 260   2014-9-18                       26                   20
# 264   2014-9-22                       19                   13
# 267   2014-9-25                       19                   13
# 269   2014-9-27                       21                   17
# 270   2014-9-28                       24                   19
# 272   2014-9-30                       22                   18
# 274   2014-10-2                       22                   19
# 292  2014-10-20                       17                   14
# 295  2014-10-23                       16                   13
# 297  2014-10-25                       16                   11
# 298  2014-10-26                       16                   13
# 299  2014-10-27                       18                   16
# 302  2014-10-30                       18                   16
# 303  2014-10-31                       23                   17
# 322  2014-11-19                       11                    9
# 323  2014-11-20                       11                    8
# 339   2014-12-6                        6                    2
# 346  2014-12-13                        7                    3
# 351  2014-12-18                       13                   12
# 358  2014-12-25                        8                    6
# 361  2014-12-28                        6                    2
# 362  2014-12-29                        6                    1
# 363  2014-12-30                        6                    1
#
#      Минимална температураC  Тачка росеC  MeanDew PointC  Min DewpointC  \
# 32                        5            4               3              1
# 33                        3            5               3              2
# 43                        3            2               1             -1
# 52                        4            5               3              1
# 63                        0            4               2             -1
# 64                        5            7               5              3
# 66                        7            7               4              2
# 67                        6            7               4              3
# 68                        4            8               4              2
# 70                        2            8               4              1
# 73                        7            6               5              2
# 74                        7            8               6              3
# 75                        5            7               6              4
# 77                        7            7               5              4
# 87                        8            7               4             -1
# 92                       11           11               9              9
# 93                        9           10               8              6
# 98                        4            7               6              3
# 99                        6            6               5              3
# 100                       9            5               4              2
# 101                       6            7               5              3
# 102                       8            8               5              2
# 103                       6            5               3              0
# 104                       3            4               2              0
# 105                       3            4               1             -6
# 106                       6            7               4              1
# 107                       6            5               2             -1
# 108                       3            4               2              0
# 122                       2            3               1             -1
# 123                       4            6               4              2
# ..                      ...          ...             ...            ...
# 252                      11           12              10              8
# 253                      10           11              10              8
# 254                      13           14              12              9
# 255                      12           14              12             11
# 257                      12           14              12              9
# 258                      13           16              14             11
# 259                      16           15              14             13
# 260                      14           16              15             13
# 264                       7            9               8              6
# 267                       7           12               9              5
# 269                      12           14              12             11
# 270                      14           15              14             13
# 272                      14           15              13             12
# 274                      14           14              13             11
# 292                      12           11              11              9
# 295                      11           14              10              7
# 297                       7            9               8              6
# 298                      12            9               8              7
# 299                      12           13              12              9
# 302                      13           15              14             12
# 303                      12           15              13             11
# 322                       7            9               7              5
# 323                       6            8               6              5
# 339                      -1            3               1             -1
# 346                       0            2               1             -1
# 351                      11           11              11             10
# 358                       2            3               2              1
# 361                      -2            1              -2             -3
# 362                      -4            2              -1             -4
# 363                      -4            2              -1             -4
#
#      Max Влажност ваздуха  Mean Влажност ваздуха  Min Влажност ваздуха  \
# 32                     93                     71                    43
# 33                     93                     79                    55
# 43                     81                     66                    45
# 52                     87                     68                    38
# 63                    100                     72                    40
# 64                     93                     77                    50
# 66                     93                     65                    29
# 67                     81                     58                    28
# 68                     87                     73                    57
# 70                     93                     76                    40
# 73                     87                     64                    24
# 74                     87                     63                    28
# 75                     93                     74                    47
# 77                     93                     68                    35
# 87                     93                     57                    18
# 92                     88                     75                    52
# 93                     88                     71                    46
# 98                     93                     68                    38
# 99                     93                     62                    31
# 100                    71                     53                    28
# 101                    87                     66                    42
# 102                    93                     63                    33
# 103                    87                     57                    25
# 104                    81                     58                    26
# 105                    87                     54                    15
# 106                    81                     59                    27
# 107                    81                     57                    28
# 108                    81                     59                    33
# 122                    87                     56                    26
# 123                    87                     62                    32
# ..                    ...                    ...                   ...
# 252                    94                     68                    38
# 253                    94                     70                    45
# 254                    94                     70                    33
# 255                   100                     75                    45
# 257                   100                     74                    35
# 258                   100                     77                    39
# 259                    94                     78                    59
# 260                    94                     74                    43
# 264                   100                     68                    35
# 267                    93                     71                    48
# 269                    94                     71                    43
# 270                    94                     72                    41
# 272                    94                     78                    44
# 274                    94                     75                    46
# 292                    88                     76                    50
# 295                    94                     76                    58
# 297                   100                     75                    41
# 298                    77                     67                    45
# 299                    94                     80                    55
# 302                   100                     89                    72
# 303                   100                     78                    40
# 322                   100                     88                    70
# 323                    93                     87                    66
# 339                   100                     85                    60
# 346                   100                     83                    53
# 351                    94                     85                    74
# 358                    93                     79                    51
# 361                   100                     76                    45
# 362                   100                     87                    62
# 363                   100                     90                    68
#
#           ...        Max ВидљивостKm  Mean ВидљивостKm  Min ВидљивостkM  \
# 32        ...                     31                16               10
# 33        ...                     31                15               10
# 43        ...                     31                15               10
# 52        ...                     31                16               10
# 63        ...                     31                15                8
# 64        ...                     31                15                7
# 66        ...                     31                11                6
# 67        ...                     26                 9                5
# 68        ...                     31                12                6
# 70        ...                     19                 9                3
# 73        ...                     31                18                5
# 74        ...                     31                19                7
# 75        ...                     31                13                5
# 77        ...                     31                18                8
# 87        ...                     31                 9                3
# 92        ...                     21                 7                3
# 93        ...                     31                11                2
# 98        ...                     31                14                6
# 99        ...                     31                14                9
# 100       ...                     31                18               10
# 101       ...                     31                16               10
# 102       ...                     31                14                9
# 103       ...                     31                17               10
# 104       ...                     31                20               10
# 105       ...                     31                20               10
# 106       ...                     31                17               10
# 107       ...                     31                15               10
# 108       ...                     31                14               10
# 122       ...                     31                16               10
# 123       ...                     31                17               10
# ..        ...                    ...               ...              ...
# 252       ...                     23                13                9
# 253       ...                     13                 8                5
# 254       ...                     31                11                5
# 255       ...                     31                12                3
# 257       ...                     26                12                5
# 258       ...                     19                 6                2
# 259       ...                     11                 6                3
# 260       ...                     19                 6                2
# 264       ...                     19                10                7
# 267       ...                     31                17               10
# 269       ...                     31                15               10
# 270       ...                     27                13                6
# 272       ...                     27                10                4
# 274       ...                     31                15                6
# 292       ...                     31                15               10
# 295       ...                     31                14                9
# 297       ...                     31                13               10
# 298       ...                     31                12               10
# 299       ...                     31                14                8
# 302       ...                     13                 6                1
# 303       ...                     31                13                3
# 322       ...                     10                 5                3
# 323       ...                     13                 6                3
# 339       ...                     31                15               10
# 346       ...                     31                19                9
# 351       ...                     31                12               10
# 358       ...                     31                19               10
# 361       ...                     31                17                8
# 362       ...                     24                10                5
# 363       ...                     27                 9                3
#
#      Max Брзина ветраKm/h  Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  \
# 32                     37                     24                          47
# 33                     32                     18                         NaN
# 43                     42                     27                          48
# 52                     29                     21                         NaN
# 63                     21                      6                         NaN
# 64                     32                     14                          42
# 66                     27                     18                         NaN
# 67                     24                     10                          34
# 68                     23                      8                         NaN
# 70                     11                      8                         NaN
# 73                     27                     16                         NaN
# 74                     24                     16                         NaN
# 75                     21                     14                         NaN
# 77                     26                     18                         NaN
# 87                     34                     16                         NaN
# 92                     26                     11                         NaN
# 93                     24                     14                         NaN
# 98                     23                     13                         NaN
# 99                     19                     10                         NaN
# 100                    13                      8                         NaN
# 101                    29                     11                         NaN
# 102                    26                     14                         NaN
# 103                    21                     13                         NaN
# 104                    21                     10                         NaN
# 105                    16                     11                         NaN
# 106                    21                     11                         NaN
# 107                    19                     13                         NaN
# 108                    23                     11                         NaN
# 122                    14                      8                         NaN
# 123                    19                     10                          40
# ..                    ...                    ...                         ...
# 252                    21                      8                         NaN
# 253                    11                      6                         NaN
# 254                    19                     11                         NaN
# 255                    19                     11                         NaN
# 257                    14                      6                         NaN
# 258                    19                      8                         NaN
# 259                    19                     13                         NaN
# 260                    19                     11                          35
# 264                    11                      6                         NaN
# 267                    26                     13                         NaN
# 269                    13                      5                         NaN
# 270                    16                      6                         NaN
# 272                    19                     13                          32
# 274                    21                      8                          35
# 292                    27                     19                         NaN
# 295                    23                     16                         NaN
# 297                    26                     13                         NaN
# 298                    27                     18                          40
# 299                    29                     16                          40
# 302                    16                     10                         NaN
# 303                    23                      8                          48
# 322                    14                     10                         NaN
# 323                    16                      8                         NaN
# 339                    14                      8                         NaN
# 346                    13                      8                         NaN
# 351                    37                     29                          60
# 358                    24                     16                         NaN
# 361                    16                     11                         NaN
# 362                    13                      8                         NaN
# 363                    14                      6                         NaN
#
#      Падавинеmm  CloudCover  Догађаји  WindDirDegrees
# 32         0.00           2       NaN             216
# 33         0.00           4       NaN             133
# 43         0.00           2       NaN             236
# 52         0.00           2       NaN             228
# 63         0.25           1       NaN             248
# 64         0.00           2       NaN             206
# 66         0.00           6       NaN             156
# 67         0.00         NaN       NaN             170
# 68         0.00           6       NaN              27
# 70         0.00           4       NaN              31
# 73         0.00           1       NaN             277
# 74         0.00         NaN       NaN             266
# 75         0.00           3       NaN             263
# 77         0.00           2       NaN             241
# 87         0.00         NaN       NaN              99
# 92         0.00           5       NaN              96
# 93         0.00           5       NaN             253
# 98         0.00           2       NaN             261
# 99         0.00           3       NaN             278
# 100        0.00           1       NaN             351
# 101        0.00           1       NaN             262
# 102        0.00           2       NaN             283
# 103        0.00           1       NaN             330
# 104        0.00           1       NaN              64
# 105        0.00           1       NaN             139
# 106        0.00           2       NaN             279
# 107        0.00           3       NaN              21
# 108        0.00           4       NaN              56
# 122        0.00           1       NaN              39
# 123        0.00           1       NaN             196
# ..          ...         ...       ...             ...
# 252        0.00           2       NaN              92
# 253        0.00           6       NaN              42
# 254        0.00           3       NaN              76
# 255        0.00           4       NaN              56
# 257        0.00           3       NaN              71
# 258        0.00           5       NaN              70
# 259        0.00           5       NaN              58
# 260        0.00           5       NaN              71
# 264        0.25           1       NaN             309
# 267        0.00           5       NaN             249
# 269        0.00           6       NaN             146
# 270        0.00           4       NaN             116
# 272        0.00           4       NaN             222
# 274        0.00           3       NaN             203
# 292        0.25           3       NaN             238
# 295        0.00           5       NaN             214
# 297        0.00           4       NaN             237
# 298        0.00           5       NaN             217
# 299        0.00           3       NaN             192
# 302        0.00           5       NaN             170
# 303        0.00           1       NaN             170
# 322        0.00           2       NaN              93
# 323        0.00           3       NaN              69
# 339        0.25           4       NaN             265
# 346        0.00           2       NaN             278
# 351        0.00           6       NaN             245
# 358        0.00           1       NaN             275
# 361        0.00           1       NaN               5
# 362        0.25           1       NaN             289
# 363        0.25           3       NaN             258
#
# [114 rows x 23 columns]

# %% [markdown]
# One way to deal with missing values is to replace them by some value. The column method `fillna()` fills all not available value cells with the value given as argument. In the example below, each missing event is replaced by the empty string.

# %%
london['Догађаји'] = london['Догађаји'].fillna('')
london[london['Догађаји'].isnull()]
# Out:
# Empty DataFrame
# Columns: [GMT, Максимална температураC, Средња температураC, Минимална температураC, Тачка росеC, MeanDew PointC, Min DewpointC, Max Влажност ваздуха, Mean Влажност ваздуха, Min Влажност ваздуха, Max Ваздушни притисак на нивоу мораhPa, Mean Ваздушни притисак на нивоу мораhPa, Min Ваздушни притисак на нивоу мораhPa, Max ВидљивостKm, Mean ВидљивостKm, Min ВидљивостkM, Max Брзина ветраKm/h, Mean Брзина ветраKm/h, Max Брзина удара ветраKm/h, Падавинеmm, CloudCover, Догађаји, WindDirDegrees]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# The empty dataframe (no rows) confirms there are no more missing event values.
#
# Another way to deal with missing values is to ignore rows with them. The `dropna()` dataframe method returns a new dataframe where all rows with at least one non-available value have been removed.

# %%
london.dropna()
# Out:
#             GMT  Максимална температураC  Средња температураC  \
# 0      2014-1-1                       11                    8
# 1      2014-1-2                       11                    9
# 2      2014-1-3                       11                    8
# 3      2014-1-4                        9                    6
# 5      2014-1-6                       12                   10
# 6      2014-1-7                       12                   10
# 7      2014-1-8                       12                    9
# 8      2014-1-9                       11                    8
# 9     2014-1-10                       11                    7
# 15    2014-1-16                       11                    8
# 16    2014-1-17                        9                    7
# 21    2014-1-22                       11                    8
# 22    2014-1-23                        8                    6
# 24    2014-1-25                       12                    9
# 25    2014-1-26                        9                    6
# 26    2014-1-27                        8                    5
# 30    2014-1-31                        9                    5
# 31     2014-2-1                        9                    7
# 32     2014-2-2                       10                    8
# 34     2014-2-4                        9                    7
# 35     2014-2-5                       10                    8
# 36     2014-2-6                       10                    8
# 37     2014-2-7                        9                    7
# 38     2014-2-8                        9                    8
# 39     2014-2-9                        8                    7
# 41    2014-2-11                        8                    5
# 42    2014-2-12                        9                    6
# 43    2014-2-13                        8                    6
# 44    2014-2-14                       12                    8
# 45    2014-2-15                       11                    8
# ..          ...                      ...                  ...
# 281   2014-10-9                       18                   14
# 282  2014-10-10                       18                   13
# 284  2014-10-12                       14                   10
# 288  2014-10-16                       18                   14
# 289  2014-10-17                       19                   16
# 291  2014-10-19                       21                   17
# 293  2014-10-21                       14                   11
# 298  2014-10-26                       16                   13
# 299  2014-10-27                       18                   16
# 300  2014-10-28                       18                   14
# 303  2014-10-31                       23                   17
# 304   2014-11-1                       18                   16
# 305   2014-11-2                       16                   13
# 306   2014-11-3                       10                    8
# 310   2014-11-7                       13                   10
# 311   2014-11-8                       14                   11
# 312   2014-11-9                       13                   10
# 336   2014-12-3                        8                    6
# 342   2014-12-9                       12                    6
# 345  2014-12-12                        9                    6
# 347  2014-12-14                       10                    4
# 350  2014-12-17                       13                    9
# 351  2014-12-18                       13                   12
# 353  2014-12-20                        9                    7
# 354  2014-12-21                       12                    8
# 355  2014-12-22                       13                   12
# 356  2014-12-23                       13                   11
# 357  2014-12-24                       12                    8
# 360  2014-12-27                        4                    3
# 364  2014-12-31                        8                    2
#
#      Минимална температураC  Тачка росеC  MeanDew PointC  Min DewpointC  \
# 0                         6            9               7              4
# 1                         6            9               6              4
# 2                         6            9               5              2
# 3                         3            8               6              2
# 5                         8           11               8              6
# 6                         8            8               7              6
# 7                         7           11               7              6
# 8                         5           11               5              2
# 9                         2            7               4              2
# 15                        6            9               6              4
# 16                        5            7               6              4
# 21                        6            7               6              4
# 22                        2            6               3              0
# 24                        5            8               6              0
# 25                        2            8               3              0
# 26                        2            4               2             -1
# 30                        1            8               4              1
# 31                        5            9               3              0
# 32                        5            4               3              1
# 34                        4            4               3              1
# 35                        5            7               4              2
# 36                        6            9               6              3
# 37                        4            9               4              0
# 38                        7            8               4              0
# 39                        4            3               1             -2
# 41                        2            6               2             -1
# 42                        2            6               2             -1
# 43                        3            2               1             -1
# 44                        3           10               4              0
# 45                        5            5               3              2
# ..                      ...          ...             ...            ...
# 281                      11           11              10              8
# 282                       9           12              10              8
# 284                       6           11               8              5
# 288                      11           14              12             11
# 289                      13           15              14             12
# 291                      14           16              13             11
# 293                       8           13               6              1
# 298                      12            9               8              7
# 299                      12           13              12              9
# 300                       9           14              12              9
# 303                      12           15              13             11
# 304                      13           15              11              6
# 305                      10           13              11              8
# 306                       6            9               7              4
# 310                       8           12               8              5
# 311                       7           11               8              5
# 312                       6            9               7              4
# 336                       4            5               3              1
# 342                      -1           11               3             -1
# 345                       2            9               4             -1
# 347                      -1            9               3             -1
# 350                       4           11              10              6
# 351                      11           11              11             10
# 353                       4            4               3              2
# 354                       3            9               6              3
# 355                      10           11               9              7
# 356                      10            9               7              5
# 357                       4           10               4             -2
# 360                       2            8               1             -1
# 364                      -4            5               2             -4
#
#      Max Влажност ваздуха  Mean Влажност ваздуха  Min Влажност ваздуха  \
# 0                      94                     86                    73
# 1                      94                     81                    60
# 2                      94                     76                    54
# 3                      93                     85                    65
# 5                      94                     78                    60
# 6                      87                     78                    63
# 7                      94                     85                    69
# 8                      94                     76                    53
# 9                      93                     85                    66
# 15                     94                     85                    67
# 16                     93                     86                    68
# 21                    100                     87                    62
# 22                    100                     81                    50
# 24                    100                     83                    48
# 25                     93                     80                    62
# 26                     87                     80                    61
# 30                    100                     90                    72
# 31                    100                     73                    46
# 32                     93                     71                    43
# 34                     87                     76                    50
# 35                     93                     75                    56
# 36                    100                     82                    62
# 37                    100                     78                    46
# 38                     93                     74                    50
# 39                     81                     65                    42
# 41                     93                     75                    43
# 42                     93                     74                    49
# 43                     81                     66                    45
# 44                     94                     81                    60
# 45                     87                     67                    51
# ..                    ...                    ...                   ...
# 281                    88                     77                    48
# 282                    94                     80                    45
# 284                   100                     84                    57
# 288                   100                     87                    58
# 289                   100                     84                    62
# 291                    94                     78                    48
# 293                    94                     65                    37
# 298                    77                     67                    45
# 299                    94                     80                    55
# 300                   100                     83                    47
# 303                   100                     78                    40
# 304                    94                     74                    39
# 305                    94                     82                    64
# 306                    94                     84                    60
# 310                    95                     80                    52
# 311                    94                     84                    64
# 312                   100                     83                    47
# 336                    93                     78                    56
# 342                   100                     86                    64
# 345                    94                     79                    59
# 347                   100                     84                    62
# 350                   100                     90                    76
# 351                    94                     85                    74
# 353                    87                     75                    53
# 354                    93                     80                    65
# 355                    94                     77                    63
# 356                    82                     72                    58
# 357                    94                     71                    38
# 360                    93                     83                    64
# 364                   100                     89                    70
#
#           ...        Max ВидљивостKm  Mean ВидљивостKm  Min ВидљивостkM  \
# 0         ...                     31                11                2
# 1         ...                     31                15                5
# 2         ...                     31                12                0
# 3         ...                     31                12                5
# 5         ...                     31                12                5
# 6         ...                     31                13                5
# 7         ...                     27                14                6
# 8         ...                     31                13                5
# 9         ...                     31                17               10
# 15        ...                     31                14                3
# 16        ...                     31                13                5
# 21        ...                     31                13                6
# 22        ...                     31                14                5
# 24        ...                     31                10                2
# 25        ...                     31                14                3
# 26        ...                     31                16                9
# 30        ...                     23                 7                0
# 31        ...                     31                13                3
# 32        ...                     31                16               10
# 34        ...                     31                14                6
# 35        ...                     26                13                6
# 36        ...                     29                12                2
# 37        ...                     31                12                3
# 38        ...                     31                14                3
# 39        ...                     31                14               10
# 41        ...                     31                14                6
# 42        ...                     31                14                5
# 43        ...                     31                15               10
# 44        ...                     31                14                5
# 45        ...                     31                15                9
# ..        ...                    ...               ...              ...
# 281       ...                     31                15                3
# 282       ...                     31                17               10
# 284       ...                     31                14                6
# 288       ...                     31                12                6
# 289       ...                     29                14                8
# 291       ...                     31                14                5
# 293       ...                     31                14                3
# 298       ...                     31                12               10
# 299       ...                     31                14                8
# 300       ...                     31                13                0
# 303       ...                     31                13                3
# 304       ...                     29                13                9
# 305       ...                     29                14                0
# 306       ...                     31                14                2
# 310       ...                     31                11                2
# 311       ...                     31                14                5
# 312       ...                     31                11                0
# 336       ...                     31                15                9
# 342       ...                     31                15                3
# 345       ...                     31                11                3
# 347       ...                     31                16                9
# 350       ...                     31                12                6
# 351       ...                     31                12               10
# 353       ...                     31                15               10
# 354       ...                     31                12               10
# 355       ...                     31                14                8
# 356       ...                     31                12               10
# 357       ...                     31                13               10
# 360       ...                     31                13                9
# 364       ...                     19                 9                0
#
#      Max Брзина ветраKm/h  Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  \
# 0                      40                     26                          66
# 1                      32                     21                          50
# 2                      50                     29                          69
# 3                      35                     21                          39
# 5                      50                     29                          61
# 6                      39                     27                          55
# 7                      24                     18                          37
# 8                      40                     26                          60
# 9                      24                     13                          32
# 15                     27                     18                          47
# 16                     29                     19                          47
# 21                     23                     14                          32
# 22                     26                     13                          45
# 24                     40                     13                          61
# 25                     37                     19                          39
# 26                     34                     23                          47
# 30                     37                     13                          50
# 31                     50                     24                          71
# 32                     37                     24                          47
# 34                     39                     21                          53
# 35                     45                     34                          66
# 36                     35                     26                          40
# 37                     39                     19                          58
# 38                     45                     32                          69
# 39                     47                     34                          66
# 41                     40                     19                          58
# 42                     52                     26                          76
# 43                     42                     27                          48
# 44                     63                     24                          90
# 45                     66                     47                          85
# ..                    ...                    ...                         ...
# 281                    39                     21                          53
# 282                    26                     14                          42
# 284                    23                      6                          37
# 288                    21                     10                          34
# 289                    24                     13                          42
# 291                    34                     21                          47
# 293                    47                     27                          69
# 298                    27                     18                          40
# 299                    29                     16                          40
# 300                    24                     11                          37
# 303                    23                      8                          48
# 304                    32                     18                          48
# 305                    27                     23                          50
# 306                    23                     14                          34
# 310                    42                     23                          42
# 311                    34                     18                          52
# 312                    14                      6                          32
# 336                    23                     16                          37
# 342                    37                     14                          52
# 345                    40                     26                          55
# 347                    29                     14                          45
# 350                    34                     21                          55
# 351                    37                     29                          60
# 353                    32                     19                          45
# 354                    35                     23                          47
# 355                    40                     32                          55
# 356                    42                     32                          61
# 357                    34                     26                          45
# 360                    42                     26                          61
# 364                    23                      8                          37
#
#      Падавинеmm  CloudCover                 Догађаји  WindDirDegrees
# 0          9.91           4                     Киша             186
# 1          1.02           2                     Киша             214
# 2          7.11           2  Киша-Олуја с грмљавином             219
# 3          9.91           4                     Киша             211
# 5          2.03           4                     Киша             219
# 6          5.08           3                     Киша             219
# 7          1.02           3                     Киша             197
# 8          0.00           4                     Киша             247
# 9          0.25           3                     Киша             216
# 15         3.05           3                     Киша             188
# 16         4.06           3                     Киша             192
# 21         0.25           5                     Киша             221
# 22         1.02           2                     Киша             265
# 24         2.03           4               Магла-Киша             249
# 25         5.08           4                     Киша             232
# 26         2.03           3                     Киша             228
# 30         7.11           5               Магла-Киша             173
# 31         0.00           2                     Киша             220
# 32         0.00           2                                      216
# 34         0.51           4                     Киша             176
# 35         2.03           4                     Киша             192
# 36         7.11           4                     Киша             190
# 37         0.51           4                     Киша             230
# 38         2.03           3                     Киша             208
# 39         0.00           3                     Киша             228
# 41         2.03           3                     Киша             222
# 42         7.87           3  Киша-Олуја с грмљавином             211
# 43         0.00           2                                      236
# 44         8.89           5                     Киша             180
# 45         0.51           4                     Киша             237
# ..          ...         ...                      ...             ...
# 281        2.03           2  Киша-Олуја с грмљавином             209
# 282        3.05           2                     Киша             207
# 284        2.03           2               Магла-Киша              53
# 288        0.25           2                     Киша             214
# 289        0.51           2                     Киша             188
# 291        0.00           3                     Киша             225
# 293        3.05           3                     Киша             268
# 298        0.00           5                                      217
# 299        0.00           3                                      192
# 300        0.00           3               Магла-Киша             181
# 303        0.00           1                                      170
# 304        0.25           3                     Киша             211
# 305       11.94           4                     Киша             207
# 306        5.08           3                     Киша             208
# 310        5.08           4                     Киша             207
# 311        2.03           3                     Киша             192
# 312        0.00           2                    Магла             212
# 336        0.51           4                     Киша              17
# 342        0.25           5                     Киша             224
# 345        1.02           3                     Киша             253
# 347        0.25           3                     Киша             215
# 350        0.25           5                     Киша             252
# 351        0.00           6                                      245
# 353        0.00           3                     Киша             251
# 354        0.00           6                     Киша             237
# 355        0.00           5                     Киша             240
# 356        0.00           4                     Киша             238
# 357        0.25           5                     Киша             262
# 360        0.00           4                     Киша             330
# 364        0.25           4                    Магла             201
#
# [128 rows x 23 columns]

# %% [markdown]
# Note that the table above has fewer than 251 of the original 365 rows, so there must be further null values besides the 114 missing events.

# %% [markdown]
# ### Changing the value type of a column

# %% [markdown]
# The type of every column in a dataframe can be determined by looking at the dataframe's `dtypes` attribute, like this:

# %%
london.dtypes
# Out:
# GMT                                         object
# Максимална температураC                      int64
# Средња температураC                          int64
# Минимална температураC                       int64
# Тачка росеC                                  int64
# MeanDew PointC                               int64
# Min DewpointC                                int64
# Max Влажност ваздуха                         int64
# Mean Влажност ваздуха                        int64
# Min Влажност ваздуха                         int64
# Max Ваздушни притисак на нивоу мораhPa       int64
# Mean Ваздушни притисак на нивоу мораhPa      int64
# Min Ваздушни притисак на нивоу мораhPa       int64
# Max ВидљивостKm                              int64
# Mean ВидљивостKm                             int64
# Min ВидљивостkM                              int64
# Max Брзина ветраKm/h                         int64
# Mean Брзина ветраKm/h                        int64
# Max Брзина удара ветраKm/h                 float64
# Падавинеmm                                 float64
# CloudCover                                 float64
# Догађаји                                    object
# WindDirDegrees                              object
# dtype: object

# %% [markdown]
# The type of all the values in a column can be changed using the <code>astype()</code> method. The following code will change the values in the <code>'WindDirDegrees'</code> column from strings (`object`) to integers (<code>int64</code>).

# %%
london['WindDirDegrees'] = london['WindDirDegrees'].astype('int64')

# %% [markdown]
# The function `to_datetime()` is needed to change the values in the `'GMT'` column from strings (`object`) to dates (`datetime64`):

# %%
london['GMT'] = to_datetime(london['GMT'])
london.dtypes
# Out:
# GMT                                        datetime64[ns]
# Максимална температураC                             int64
# Средња температураC                                 int64
# Минимална температураC                              int64
# Тачка росеC                                         int64
# MeanDew PointC                                      int64
# Min DewpointC                                       int64
# Max Влажност ваздуха                                int64
# Mean Влажност ваздуха                               int64
# Min Влажност ваздуха                                int64
# Max Ваздушни притисак на нивоу мораhPa              int64
# Mean Ваздушни притисак на нивоу мораhPa             int64
# Min Ваздушни притисак на нивоу мораhPa              int64
# Max ВидљивостKm                                     int64
# Mean ВидљивостKm                                    int64
# Min ВидљивостkM                                     int64
# Max Брзина ветраKm/h                                int64
# Mean Брзина ветраKm/h                               int64
# Max Брзина удара ветраKm/h                        float64
# Падавинеmm                                        float64
# CloudCover                                        float64
# Догађаји                                           object
# WindDirDegrees                                      int64
# dtype: object

# %% [markdown]
# Values of type `datetime64` can be created using the `datetime()` function where the first integer argument is the year, the second the month and the third the day.
# The code below will get and display the row in the dataframe whose `'GMT'` value is 4th June 2014.

# %%
london[london['GMT'] == datetime(2014, 6, 4)]
# Out:
#            GMT  Максимална температураC  Средња температураC  \
# 154 2014-06-04                       14                   11
#
#      Минимална температураC  Тачка росеC  MeanDew PointC  Min DewpointC  \
# 154                       8           11               9              3
#
#      Max Влажност ваздуха  Mean Влажност ваздуха  Min Влажност ваздуха  \
# 154                    94                     78                    47
#
#           ...        Max ВидљивостKm  Mean ВидљивостKm  Min ВидљивостkM  \
# 154       ...                     31                12                7
#
#      Max Брзина ветраKm/h  Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  \
# 154                    47                     13                          64
#
#      Падавинеmm  CloudCover                 Догађаји  WindDirDegrees
# 154        2.03           4  Киша-Олуја с грмљавином             230
#
# [1 rows x 23 columns]

# %% [markdown]
# Queries such as 'Return all the rows where the date is between 8 December and 12 December' can be made:

# %%
dates = london['GMT']
start = datetime(2014, 12, 8)
end = datetime(2014, 12, 12)
london[(dates >= start) & (dates <= end)]
# Out:
#            GMT  Максимална температураC  Средња температураC  \
# 341 2014-12-08                        7                    4
# 342 2014-12-09                       12                    6
# 343 2014-12-10                        9                    7
# 344 2014-12-11                       10                    8
# 345 2014-12-12                        9                    6
#
#      Минимална температураC  Тачка росеC  MeanDew PointC  Min DewpointC  \
# 341                       1            2               1             -1
# 342                      -1           11               3             -1
# 343                       6           11               3              1
# 344                       5            6               3              2
# 345                       2            9               4             -1
#
#      Max Влажност ваздуха  Mean Влажност ваздуха  Min Влажност ваздуха  \
# 341                    93                     76                    51
# 342                   100                     86                    64
# 343                    90                     70                    44
# 344                    82                     72                    51
# 345                    94                     79                    59
#
#           ...        Max ВидљивостKm  Mean ВидљивостKm  Min ВидљивостkM  \
# 341       ...                     31                17               10
# 342       ...                     31                15                3
# 343       ...                     31                18                3
# 344       ...                     31                15               10
# 345       ...                     31                11                3
#
#      Max Брзина ветраKm/h  Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  \
# 341                    23                     13                         NaN
# 342                    37                     14                          52
# 343                    40                     27                         NaN
# 344                    40                     31                         NaN
# 345                    40                     26                          55
#
#      Падавинеmm  CloudCover  Догађаји  WindDirDegrees
# 341        0.00           2      Киша             270
# 342        0.25           5      Киша             224
# 343        0.00           2      Киша             246
# 344        0.25           2      Киша             246
# 345        1.02           3      Киша             253
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Tasks
#
# Now that the wind direction is given by a number, write code to select all days that had a northerly wind. Hint: select the rows where the direction is greater or equal than 350 **or** smaller or equal than 10, as the compass rose shows.

# %%
london[(london["WindDirDegrees"] >= 350) | (london["WindDirDegrees"] <= 10)]
# Out:
#            GMT  Максимална температураC  Средња температураC  \
# 84  2014-03-26                        9                    6
# 90  2014-04-01                       19                   13
# 100 2014-04-11                       16                   12
# 110 2014-04-21                       19                   12
# 174 2014-06-24                       24                   19
# 179 2014-06-29                       19                   16
# 190 2014-07-10                       22                   18
# 208 2014-07-28                       23                   19
# 249 2014-09-07                       21                   17
# 250 2014-09-08                       22                   16
# 335 2014-12-02                        8                    7
# 361 2014-12-28                        6                    2
#
#      Минимална температураC  Тачка росеC  MeanDew PointC  Min DewpointC  \
# 84                        2            4               2             -1
# 90                        7           11               9              6
# 100                       9            5               4              2
# 110                       5           11               8              4
# 174                      13           15              12              9
# 179                      12           11               9              5
# 190                      14           13              11              9
# 208                      14           16              12              9
# 249                      13           14              12              8
# 250                      10           13               9              7
# 335                       6            7               4              2
# 361                      -2            1              -2             -3
#
#      Max Влажност ваздуха  Mean Влажност ваздуха  Min Влажност ваздуха  \
# 84                    100                     80                    39
# 90                    100                     80                    39
# 100                    71                     53                    28
# 110                   100                     78                    31
# 174                    94                     66                    27
# 179                    88                     65                    31
# 190                    82                     64                    44
# 208                    94                     66                    33
# 249                    94                     71                    41
# 250                    94                     64                    28
# 335                   100                     80                    62
# 361                   100                     76                    45
#
#           ...        Max ВидљивостKm  Mean ВидљивостKm  Min ВидљивостkM  \
# 84        ...                     27                10                1
# 90        ...                     19                 7                0
# 100       ...                     31                18               10
# 110       ...                     26                 7                0
# 174       ...                     31                12                0
# 179       ...                     31                16               10
# 190       ...                     31                19               10
# 208       ...                     26                12                2
# 249       ...                     23                10                2
# 250       ...                     27                12                5
# 335       ...                     31                11                1
# 361       ...                     31                17                8
#
#      Max Брзина ветраKm/h  Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  \
# 84                     26                     10                         NaN
# 90                     16                      5                         NaN
# 100                    13                      8                         NaN
# 110                    14                      6                         NaN
# 174                    23                      8                          37
# 179                    19                     10                         NaN
# 190                    16                     14                         NaN
# 208                    21                     10                         NaN
# 249                    11                      6                         NaN
# 250                    11                      6                         NaN
# 335                    27                     13                         NaN
# 361                    16                     11                         NaN
#
#      Падавинеmm  CloudCover                       Догађаји  WindDirDegrees
# 84         2.03           4                     Магла-Киша               3
# 90         0.00           4                     Магла-Киша               6
# 100        0.00           1                                            351
# 110        9.91           3  Магла-Киша-Олуја с грмљавином             356
# 174        0.00           3                          Магла             350
# 179        0.00           2                           Киша               9
# 190        0.00           3                                              1
# 208       17.02           2        Киша-Олуја с грмљавином               3
# 249        0.00           4                                            354
# 250        0.00           1                                            351
# 335        1.02           5                           Киша             359
# 361        0.00           1                                              5
#
# [12 rows x 23 columns]

# %% [markdown]
# In the code cell below, write code to get and display all the rows in the dataframe that are beween 1 April 2014 and
# 11 April 2014.

# %%
london[(london['GMT'] > datetime(2014, 4, 1)) & (london['GMT'] < datetime(2014, 4, 11))]
# Out:
#           GMT  Максимална температураC  Средња температураC  \
# 91 2014-04-02                       18                   14
# 92 2014-04-03                       18                   14
# 93 2014-04-04                       15                   12
# 94 2014-04-05                       14                   10
# 95 2014-04-06                       16                   14
# 96 2014-04-07                       14                   11
# 97 2014-04-08                       14                    9
# 98 2014-04-09                       17                   10
# 99 2014-04-10                       16                   11
#
#     Минимална температураC  Тачка росеC  MeanDew PointC  Min DewpointC  \
# 91                      11           11               9              7
# 92                      11           11               9              9
# 93                       9           10               8              6
# 94                       6           11               8              5
# 95                      12           12              12             11
# 96                       8           12              11              6
# 97                       5            6               3             -1
# 98                       4            7               6              3
# 99                       6            6               5              3
#
#     Max Влажност ваздуха  Mean Влажност ваздуха  Min Влажност ваздуха  \
# 91                    88                     71                    48
# 92                    88                     75                    52
# 93                    88                     71                    46
# 94                   100                     83                    56
# 95                    94                     88                    67
# 96                    94                     87                    76
# 97                    87                     64                    26
# 98                    93                     68                    38
# 99                    93                     62                    31
#
#          ...        Max ВидљивостKm  Mean ВидљивостKm  Min ВидљивостkM  \
# 91       ...                     10                 8                5
# 92       ...                     21                 7                3
# 93       ...                     31                11                2
# 94       ...                     31                12                1
# 95       ...                     31                12                5
# 96       ...                     31                14                5
# 97       ...                     31                15               10
# 98       ...                     31                14                6
# 99       ...                     31                14                9
#
#     Max Брзина ветраKm/h  Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  \
# 91                    23                     13                         NaN
# 92                    26                     11                         NaN
# 93                    24                     14                         NaN
# 94                    26                     13                          50
# 95                    35                     21                          48
# 96                    29                     23                          42
# 97                    39                     23                         NaN
# 98                    23                     13                         NaN
# 99                    19                     10                         NaN
#
#     Падавинеmm  CloudCover    Догађаји  WindDirDegrees
# 91        0.00           1        Киша              85
# 92        0.00           5                          96
# 93        0.00           5                         253
# 94        0.00           5  Магла-Киша             197
# 95        2.03           6        Киша             213
# 96        2.03           5        Киша             209
# 97        0.00           2        Киша             269
# 98        0.00           2                         261
# 99        0.00           3                         278
#
# [9 rows x 23 columns]

# %% [markdown]
# In the cell below, write two lines of code to display the first five rows that have a missing value in the `'Max Gust SpeedKm/h'` column. Hint: first select the missing value rows and store them in a new dataframe, then display the first five rows of the new dataframe.

# %%
max_udar_vetra = london[london['Max Брзина удара ветраKm/h'].isnull()]
max_udar_vetra.head()
# Out:
#           GMT  Максимална температураC  Средња температураC  \
# 4  2014-01-05                       12                    7
# 10 2014-01-11                        9                    4
# 11 2014-01-12                       10                    4
# 12 2014-01-13                        9                    7
# 13 2014-01-14                        7                    4
#
#     Минимална температураC  Тачка росеC  MeanDew PointC  Min DewpointC  \
# 4                        1           11               4             -1
# 10                       0            7               3             -1
# 11                      -2            9               3             -2
# 12                       5            8               4              3
# 13                       1            5               2              0
#
#     Max Влажност ваздуха  Mean Влажност ваздуха  Min Влажност ваздуха  \
# 4                    100                     88                    77
# 10                   100                     80                    51
# 11                   100                     91                    79
# 12                    93                     85                    71
# 13                   100                     82                    55
#
#          ...        Max ВидљивостKm  Mean ВидљивостKm  Min ВидљивостkM  \
# 4        ...                     31                14                5
# 10       ...                     31                12                6
# 11       ...                     31                 9                1
# 12       ...                     31                16                5
# 13       ...                     31                15               10
#
#     Max Брзина ветраKm/h  Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  \
# 4                     35                     16                         NaN
# 10                    24                     14                         NaN
# 11                    32                     10                         NaN
# 12                    34                     19                         NaN
# 13                    21                     13                         NaN
#
#     Падавинеmm  CloudCover    Догађаји  WindDirDegrees
# 4         0.25           5        Киша             199
# 10        0.00           4        Киша             259
# 11        0.51           6  Магла-Киша             126
# 12        5.08           2        Киша             205
# 13        0.25           3        Киша             242
#
# [5 rows x 23 columns]

# %% [markdown]
# **Now go back to the Exercise 4 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ## Exercise 5: Every picture tells a story
#
# The following line of code tells Jupyter to display inside this notebook any graph that is created.

# %%
# %matplotlib inline

# %% [markdown]
# The `plot()` method can make a graph of the values in a column. Gridlines are turned on by the `grid` argument.

# %%
london['Max Брзина ветраKm/h'].plot(grid=True)

# %% [markdown]
# The graph can be made bigger by giving the method a `figsize=(x,y)` argument where `x` and `y` are integers that determine the length of the x-axis and y-axis.

# %%
london['Max Брзина ветраKm/h'].plot(grid=True, figsize=(10,5))

# %% [markdown]
# Multiple lines can be plotted by selecting multiple columns.

# %%
london[['Max Брзина ветраKm/h', 'Mean Брзина ветраKm/h']].plot(grid=True, figsize=(10,5))

# %% [markdown]
# ### Task
#
# In the cell below, write code to plot the minimum, mean, and maximum temperature during 2014 in London.

# %%
london[['Максимална температураC', 'Средња температураC', "Минимална температураC"]].plot(grid=True, figsize=(10,5))

# %% [markdown]
# **Now go back to the Exercise 5 step in FutureLearn to discuss and mark it complete.**

# %% [markdown]
# ## Exercise 6: Changing a dataframe's index
# Changing the dataframe's index from the default to `datetime64` values is done by assigning to the dataframe's `index` attribute the contents of the `'GMT`' column, like this:

# %%
london.index = london['GMT']
london.head(2)
# Out:
#                   GMT  Максимална температураC  Средња температураC  \
# GMT
# 2014-01-01 2014-01-01                       11                    8
# 2014-01-02 2014-01-02                       11                    9
#
#             Минимална температураC  Тачка росеC  MeanDew PointC  \
# GMT
# 2014-01-01                       6            9               7
# 2014-01-02                       6            9               6
#
#             Min DewpointC  Max Влажност ваздуха  Mean Влажност ваздуха  \
# GMT
# 2014-01-01              4                    94                     86
# 2014-01-02              4                    94                     81
#
#             Min Влажност ваздуха       ...        Max ВидљивостKm  \
# GMT                                    ...
# 2014-01-01                    73       ...                     31
# 2014-01-02                    60       ...                     31
#
#             Mean ВидљивостKm  Min ВидљивостkM  Max Брзина ветраKm/h  \
# GMT
# 2014-01-01                11                2                    40
# 2014-01-02                15                5                    32
#
#             Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  Падавинеmm  \
# GMT
# 2014-01-01                     26                          66        9.91
# 2014-01-02                     21                          50        1.02
#
#             CloudCover  Догађаји  WindDirDegrees
# GMT
# 2014-01-01           4      Киша             186
# 2014-01-02           2      Киша             214
#
# [2 rows x 23 columns]

# %% [markdown]
# The `irow()` method can still be used to get and display rows, but now you can now also use the `datetime64` index to get a row using the dataframe's `ix` (index) property, like this:

# %%
london.ix[datetime(2014, 1, 1)]
# Out:
# GMT                                        2014-01-01 00:00:00
# Максимална температураC                                     11
# Средња температураC                                          8
# Минимална температураC                                       6
# Тачка росеC                                                  9
# MeanDew PointC                                               7
# Min DewpointC                                                4
# Max Влажност ваздуха                                        94
# Mean Влажност ваздуха                                       86
# Min Влажност ваздуха                                        73
# Max Ваздушни притисак на нивоу мораhPa                    1002
# Mean Ваздушни притисак на нивоу мораhPa                    993
# Min Ваздушни притисак на нивоу мораhPa                     984
# Max ВидљивостKm                                             31
# Mean ВидљивостKm                                            11
# Min ВидљивостkM                                              2
# Max Брзина ветраKm/h                                        40
# Mean Брзина ветраKm/h                                       26
# Max Брзина удара ветраKm/h                                  66
# Падавинеmm                                                9.91
# CloudCover                                                   4
# Догађаји                                                  Киша
# WindDirDegrees                                             186
# Name: 2014-01-01 00:00:00, dtype: object

# %% [markdown]
# A query such as *'Return all the rows where the date is between December 8th and December 12th'* can now be done  succinctly like this:

# %%
london.ix[datetime(2014,12,8) : datetime(2014,12,12)]

#The meaning of the above code is get the rows beween and including 
#the indices datetime(2014,12,8) and datetime(2014,12,12)
# Out:
#                   GMT  Максимална температураC  Средња температураC  \
# GMT
# 2014-12-08 2014-12-08                        7                    4
# 2014-12-09 2014-12-09                       12                    6
# 2014-12-10 2014-12-10                        9                    7
# 2014-12-11 2014-12-11                       10                    8
# 2014-12-12 2014-12-12                        9                    6
#
#             Минимална температураC  Тачка росеC  MeanDew PointC  \
# GMT
# 2014-12-08                       1            2               1
# 2014-12-09                      -1           11               3
# 2014-12-10                       6           11               3
# 2014-12-11                       5            6               3
# 2014-12-12                       2            9               4
#
#             Min DewpointC  Max Влажност ваздуха  Mean Влажност ваздуха  \
# GMT
# 2014-12-08             -1                    93                     76
# 2014-12-09             -1                   100                     86
# 2014-12-10              1                    90                     70
# 2014-12-11              2                    82                     72
# 2014-12-12             -1                    94                     79
#
#             Min Влажност ваздуха       ...        Max ВидљивостKm  \
# GMT                                    ...
# 2014-12-08                    51       ...                     31
# 2014-12-09                    64       ...                     31
# 2014-12-10                    44       ...                     31
# 2014-12-11                    51       ...                     31
# 2014-12-12                    59       ...                     31
#
#             Mean ВидљивостKm  Min ВидљивостkM  Max Брзина ветраKm/h  \
# GMT
# 2014-12-08                17               10                    23
# 2014-12-09                15                3                    37
# 2014-12-10                18                3                    40
# 2014-12-11                15               10                    40
# 2014-12-12                11                3                    40
#
#             Mean Брзина ветраKm/h  Max Брзина удара ветраKm/h  Падавинеmm  \
# GMT
# 2014-12-08                     13                         NaN        0.00
# 2014-12-09                     14                          52        0.25
# 2014-12-10                     27                         NaN        0.00
# 2014-12-11                     31                         NaN        0.25
# 2014-12-12                     26                          55        1.02
#
#             CloudCover  Догађаји  WindDirDegrees
# GMT
# 2014-12-08           2      Киша             270
# 2014-12-09           5      Киша             224
# 2014-12-10           2      Киша             246
# 2014-12-11           2      Киша             246
# 2014-12-12           3      Киша             253
#
# [5 rows x 23 columns]

# %% [markdown]
# Now we have a `datetime64` index, let's plot `'Max Wind SpeedKm/h'` again:

# %%
london['Max Брзина ветраKm/h'].plot(grid=True, figsize=(10,5))

# %% [markdown]
# Now it is much clearer that the worst winds were in mid February.
#
# ### Task
# Use the code cell below to plot the values of `'Mean Humidity'` during spring (full months of March, April and May).

# %%
london.ix[datetime(2014,3,1) : datetime(2014,5,31)]["Mean Влажност ваздуха"].plot(grid=True, figsize=(10,5))

# %% [markdown]
# **Now go back to the Exercise 6 step in FutureLearn to discuss and mark it complete.**
